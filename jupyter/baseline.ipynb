# %%
import csv
import glob
import pandas as pd
import numpy as np
import PIL
import cv2

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
import torchmetrics

import timm
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import copy
import os
import wandb
import time

# %% [markdown]
# # 1. 데이터 로드

# %%
train_dir = '../../input/data/train'
test_dir = '../../input/data/eval'
save_dir = '../saved/models/'

# %% [markdown]
# ### 하이퍼파라미터

# %%
model_name = 'efficientnet_b1'
#model_name = 'vit_base_patch16_384'
learning_rate = 2e-5
batch_size = 64
step_size = 5
epochs = 30
earlystop = 5

A_transform = {
    'train':
        A.Compose([
            # A.Resize(512, 512),
            # A.RandomCrop(384, 384),
            A.Resize(224, 224),
            A.HorizontalFlip(p=0.5),
            A.Cutout(num_holes=8, max_h_size=32,max_w_size=32),
            A.ElasticTransform(),
            A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ToTensorV2()
        ]),
    'valid':
        A.Compose([
            # A.Resize(384, 384),
            A.Resize(224, 224),

            A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ToTensorV2()
        ]),
    'test':
        A.Compose([
            # A.Resize(384, 384),
            A.Resize(224, 224),
            A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ToTensorV2()
        ])
}
# Out:
# /opt/conda/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:688: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   warnings.warn(

# %%
class LoadCSV():
    def __init__(self, dir):
        self.dir = dir
        self.img_dir =train_dir + '/new_images/'
        self.origin_csv_path = train_dir + '/train.csv'
        self.trans_csv_path = train_dir + '/trans_train.csv'
        
        if not os.path.exists(self.trans_csv_path):
            self._makeCSV()
        self.df = pd.read_csv(self.trans_csv_path)
        #self.df = self.df[:200]
    def _makeCSV(self):        
        with open(self.trans_csv_path, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["path", "label"])

            df = pd.read_csv(self.origin_csv_path)
            for idx in range(len(df)):
                data = df.iloc[idx]
                img_path_base = os.path.join(os.path.join(self.img_dir, data['path']), '*')
                for img_path in glob.glob(img_path_base):
                    label = 0
                    if "incorrect" in img_path:
                        label+=6
                    elif 'normal' in img_path:
                        label+=12
                    elif data['gender']=='female':
                        label+=3
                    elif data['age'] >= 30 and data['age'] < 60:
                        label+=1
                    elif data['age'] >= 60:
                        label+=2
                    writer.writerow([img_path, label])
        f.close()

class MaskDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        super().__init__()
        self.df = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        class_id = torch.tensor(self.df['label'].iloc[idx])
        img = PIL.Image.open(self.df['path'].iloc[idx])
        img = np.array(img.convert("RGB"))
        if self.transform:
            img = self.transform(image=img)['image']
        return img, class_id

# %% [markdown]
# # 2. 모델 설계

# %%
class MyModel(nn.Module):
    def __init__(self, model_name, num_classes):
        super(MyModel, self).__init__()
        self.num_classes = num_classes
        self.model = timm.create_model(model_name, pretrained=True)

        n_features = self.model.classifier.in_features
        self.model.classifier = torch.nn.Linear(in_features=n_features, out_features=num_classes, bias=True)
        torch.nn.init.xavier_uniform_(self.model.classifier.weight)
        stdv = 1/np.sqrt(self.num_classes)
        self.model.classifier.bias.data.uniform_(-stdv, stdv)

        # n_features = self.model.head.in_features
        # self.model.head = torch.nn.Linear(in_features=n_features, out_features=self.num_classes, bias=True)
        # torch.nn.init.xavier_uniform_(self.model.head.weight)
        # stdv = 1/np.sqrt(self.num_classes)
        # self.model.head.bias.data.uniform_(-stdv, stdv)
        
    def forward(self, x):
        return self.model(x)

# %%
mask_csv = LoadCSV(train_dir)
df_train, df_val = train_test_split(mask_csv.df, random_state=42, stratify=mask_csv.df.to_numpy()[:,-1])
mask_train = MaskDataset(df_train,  transform=A_transform['train'])
mask_valid = MaskDataset(df_val,  transform=A_transform['valid'])

train_loader = DataLoader(mask_train, batch_size=batch_size, drop_last=False, num_workers=8, pin_memory=True)
valid_loader = DataLoader(mask_valid, batch_size=batch_size, drop_last=False, num_workers=8, pin_memory=True)
dataloaders = {'train': train_loader, 'valid':valid_loader}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MyModel(model_name, 18).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), learning_rate)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50, eta_min=0)

# %% [markdown]
# # 3. 학습

# %%
today = time.strftime('%Y%m%d_%H%M%S', time.localtime(time.time()))
if not os.path.exists(save_dir + today):
    os.makedirs(save_dir + today)

import wandb
wandb.login()

wandb.init(project=model_name, entity='nudago')
wandb_config = wandb.config
wandb_config.learning_rate = learning_rate
wandb_config.batch_size = batch_size
wandb_config.step_size = step_size
wandb_config.epochs = epochs
# wandb.log({"loss:" loss.item()}, step=example_ct)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: nudago (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">golden-deluge-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nudago/efficientnet_b1" target="_blank">https://wandb.ai/nudago/efficientnet_b1</a><br/>
#                 Run page: <a href="https://wandb.ai/nudago/efficientnet_b1/runs/1wpusamz" target="_blank">https://wandb.ai/nudago/efficientnet_b1/runs/1wpusamz</a><br/>
#                 Run data is saved locally in <code>/opt/ml/image-classification-level1-04/jupyter/wandb/run-20210831_173321-1wpusamz</code><br/><br/>

# %%
train_acc = torchmetrics.Accuracy()

# %%
earlystop_value = 0
best_model = copy.deepcopy(model.state_dict())
best_acc = 0
best_loss = 999999999

wandb.watch(model, criterion, log='all')
for epoch in range(epochs):
    if earlystop_value >= earlystop:
        break
    train_loss, valid_loss, train_acc_list, valid_acc_list = 0, 0, [],[]
 
    for phase in ['train', 'valid']:
        if phase == 'train':
            model.train()
        else:
            model.eval()
            
        running_loss = 0.0
        running_corrects = 0
        with tqdm(dataloaders[phase], total=dataloaders[phase].__len__(), unit="batch") as train_bar:
            for batch_idx, (inputs, labels) in enumerate(train_bar):
                example_ct = epoch * len(dataloaders[phase]) + batch_idx
                #print(example_ct)
                train_bar.set_description(f"{phase} Epoch {epoch} ")
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                outputs = outputs.cpu().detach().numpy()
                labels = labels.cpu().detach().numpy()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += (np.argmax(outputs, axis=1)== labels).mean()
                epoch_loss = running_loss / len(dataloaders[phase].dataset)
                epoch_acc = running_corrects / len(dataloaders[phase].dataset)
                train_bar.set_postfix(loss=epoch_loss, acc=epoch_acc)
                wandb.log({f'{phase}_loss':loss.item(),  f'{phase}_acc':(np.argmax(outputs, axis=1)== labels).mean()}, step=example_ct)
                # else:
                #     wandb.log({'valid_loss':loss.item(),  'valid_acc':running_corrects})

        lr_scheduler.step()
        if phase=='valid':
            #print(epoch_loss, best_loss)
            if epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(best_model_wts, f'{save_dir}{today}/baseline_{model_name}_lr{learning_rate}_stepLR{step_size}_batch{batch_size}_epoch{epoch}_valid_loss_{epoch_loss:.5f}.pt')
                earlystop_value = 0
            else:
                earlystop_value += 1
    
model.load_state_dict(best_model_wts)
# Out:
# train Epoch 0 : 100%|██████████| 222/222 [01:09<00:00,  3.19batch/s, acc=0.00922, loss=1.61]
# valid Epoch 0 :   0%|          | 0/74 [00:00<?, ?batch/s, acc=0.000175, loss=0.00773]wandb: WARNING Step must only increase in log calls.  Step 0 < 221; dropping {'valid_loss': 0.5706337690353394, 'valid_acc': 0.828125}.
# valid Epoch 0 :   1%|▏         | 1/74 [00:01<00:58,  1.26batch/s, acc=0.000341, loss=0.0174] wandb: WARNING Step must only increase in log calls.  Step 1 < 221; dropping {'valid_loss': 0.7126429677009583, 'valid_acc': 0.78125}.
# valid Epoch 0 :   3%|▎         | 2/74 [00:01<00:46,  1.56batch/s, acc=0.000529, loss=0.024] wandb: WARNING Step must only increase in log calls.  Step 2 < 221; dropping {'valid_loss': 0.4917585849761963, 'valid_acc': 0.890625}.
# valid Epoch 0 :   3%|▎         | 2/74 [00:01<00:46,  1.56batch/s, acc=0.000724, loss=0.0311]wandb: WARNING Step must only increase in log calls.  Step 3 < 221; dropping {'valid_loss': 0.5178321599960327, 'valid_acc': 0.921875}.
# valid Epoch 0 :   5%|▌         | 4/74 [00:01<00:32,  2.14batch/s, acc=0.000906, loss=0.0388]wandb: WARNING Step must only increase in log calls.  Step 4 < 221; dropping {'valid_loss': 0.568619430065155, 'valid_acc': 0.859375}.
# valid Epoch 0 :   5%|▌         | 4/74 [00:01<00:32,  2.14batch/s, acc=0.00111, loss=0.0439] wandb: WARNING Step must only increase in log calls.  Step 5 < 221; dropping {'valid_loss': 0.3809950649738312, 'valid_acc': 0.953125}.
# valid Epoch 0 :   8%|▊         | 6/74 [00:01<00:23,  2.92batch/s, acc=0.00129, loss=0.0524]wandb: WARNING Step must only increase in log calls.  Step 6 < 221; dropping {'valid_loss': 0.6253644824028015, 'valid_acc': 0.875}.
# valid Epoch 0 :   8%|▊         | 6/74 [00:01<00:23,  2.92batch/s, acc=0.00148, loss=0.0585]wandb: WARNING Step must only increase in log calls.  Step 7 < 221; dropping {'valid_loss': 0.452674001455307, 'valid_acc': 0.90625}.
# valid Epoch 0 :  11%|█         | 8/74 [00:01<00:16,  3.89batch/s, acc=0.00167, loss=0.0658]wandb: WARNING Step must only increase in log calls.  Step 8 < 221; dropping {'valid_loss': 0.538573682308197, 'valid_acc': 0.890625}.
# valid Epoch 0 :  11%|█         | 8/74 [00:01<00:16,  3.89batch/s, acc=0.00185, loss=0.0741]wandb: WARNING Step must only increase in log calls.  Step 9 < 221; dropping {'valid_loss': 0.6084893345832825, 'valid_acc': 0.828125}.
# valid Epoch 0 :  14%|█▎        | 10/74 [00:01<00:12,  5.08batch/s, acc=0.00204, loss=0.0808]wandb: WARNING Step must only increase in log calls.  Step 10 < 221; dropping {'valid_loss': 0.4982539713382721, 'valid_acc': 0.90625}.
# valid Epoch 0 :  14%|█▎        | 10/74 [00:01<00:12,  5.08batch/s, acc=0.00224, loss=0.087] wandb: WARNING Step must only increase in log calls.  Step 11 < 221; dropping {'valid_loss': 0.4574545919895172, 'valid_acc': 0.9375}.
# valid Epoch 0 :  16%|█▌        | 12/74 [00:01<00:09,  6.40batch/s, acc=0.00243, loss=0.0938]wandb: WARNING Step must only increase in log calls.  Step 12 < 221; dropping {'valid_loss': 0.5028550028800964, 'valid_acc': 0.90625}.
# valid Epoch 0 :  16%|█▌        | 12/74 [00:01<00:09,  6.40batch/s, acc=0.00263, loss=0.0996]wandb: WARNING Step must only increase in log calls.  Step 13 < 221; dropping {'valid_loss': 0.42376333475112915, 'valid_acc': 0.9375}.
# valid Epoch 0 :  19%|█▉        | 14/74 [00:01<00:07,  7.94batch/s, acc=0.00281, loss=0.107] wandb: WARNING Step must only increase in log calls.  Step 14 < 221; dropping {'valid_loss': 0.5198749899864197, 'valid_acc': 0.875}.
# valid Epoch 0 :  19%|█▉        | 14/74 [00:01<00:07,  7.94batch/s, acc=0.00302, loss=0.112]wandb: WARNING Step must only increase in log calls.  Step 15 < 221; dropping {'valid_loss': 0.3946191072463989, 'valid_acc': 0.953125}.
# valid Epoch 0 :  22%|██▏       | 16/74 [00:01<00:06,  9.02batch/s, acc=0.0032, loss=0.12]  wandb: WARNING Step must only increase in log calls.  Step 16 < 221; dropping {'valid_loss': 0.5711427927017212, 'valid_acc': 0.890625}.
# valid Epoch 0 :  22%|██▏       | 16/74 [00:02<00:06,  9.02batch/s, acc=0.0034, loss=0.125]wandb: WARNING Step must only increase in log calls.  Step 17 < 221; dropping {'valid_loss': 0.3948255181312561, 'valid_acc': 0.90625}.
# valid Epoch 0 :  24%|██▍       | 18/74 [00:02<00:05, 10.51batch/s, acc=0.00359, loss=0.131]wandb: WARNING Step must only increase in log calls.  Step 18 < 221; dropping {'valid_loss': 0.46569567918777466, 'valid_acc': 0.90625}.
# valid Epoch 0 :  24%|██▍       | 18/74 [00:02<00:05, 10.51batch/s, acc=0.00378, loss=0.137]wandb: WARNING Step must only increase in log calls.  Step 19 < 221; dropping {'valid_loss': 0.39341509342193604, 'valid_acc': 0.921875}.
# valid Epoch 0 :  27%|██▋       | 20/74 [00:02<00:04, 11.87batch/s, acc=0.00397, loss=0.144]wandb: WARNING Step must only increase in log calls.  Step 20 < 221; dropping {'valid_loss': 0.5126532912254333, 'valid_acc': 0.875}.
# valid Epoch 0 :  27%|██▋       | 20/74 [00:02<00:04, 11.87batch/s, acc=0.00415, loss=0.15] wandb: WARNING Step must only increase in log calls.  Step 21 < 221; dropping {'valid_loss': 0.49421894550323486, 'valid_acc': 0.859375}.
# valid Epoch 0 :  30%|██▉       | 22/74 [00:02<00:03, 13.30batch/s, acc=0.00434, loss=0.157]wandb: WARNING Step must only increase in log calls.  Step 22 < 221; dropping {'valid_loss': 0.5033591389656067, 'valid_acc': 0.90625}.
# valid Epoch 0 :  30%|██▉       | 22/74 [00:02<00:03, 13.30batch/s, acc=0.00454, loss=0.163]wandb: WARNING Step must only increase in log calls.  Step 23 < 221; dropping {'valid_loss': 0.4170920252799988, 'valid_acc': 0.9375}.
# valid Epoch 0 :  32%|███▏      | 24/74 [00:02<00:03, 14.15batch/s, acc=0.00473, loss=0.172]wandb: WARNING Step must only increase in log calls.  Step 24 < 221; dropping {'valid_loss': 0.6879432797431946, 'valid_acc': 0.875}.
# valid Epoch 0 :  32%|███▏      | 24/74 [00:02<00:03, 14.15batch/s, acc=0.0049, loss=0.181] wandb: WARNING Step must only increase in log calls.  Step 25 < 221; dropping {'valid_loss': 0.6679298877716064, 'valid_acc': 0.8125}.
# valid Epoch 0 :  35%|███▌      | 26/74 [00:02<00:03, 15.17batch/s, acc=0.00509, loss=0.188]wandb: WARNING Step must only increase in log calls.  Step 26 < 221; dropping {'valid_loss': 0.4891909956932068, 'valid_acc': 0.890625}.
# valid Epoch 0 :  35%|███▌      | 26/74 [00:02<00:03, 15.17batch/s, acc=0.00527, loss=0.196]wandb: WARNING Step must only increase in log calls.  Step 27 < 221; dropping {'valid_loss': 0.6029641032218933, 'valid_acc': 0.875}.
# valid Epoch 0 :  38%|███▊      | 28/74 [00:02<00:02, 16.04batch/s, acc=0.00547, loss=0.202]wandb: WARNING Step must only increase in log calls.  Step 28 < 221; dropping {'valid_loss': 0.4360603988170624, 'valid_acc': 0.9375}.
# valid Epoch 0 :  38%|███▊      | 28/74 [00:02<00:02, 16.04batch/s, acc=0.00566, loss=0.208]wandb: WARNING Step must only increase in log calls.  Step 29 < 221; dropping {'valid_loss': 0.41903042793273926, 'valid_acc': 0.921875}.
# valid Epoch 0 :  41%|████      | 30/74 [00:02<00:03, 14.62batch/s, acc=0.00586, loss=0.214]wandb: WARNING Step must only increase in log calls.  Step 30 < 221; dropping {'valid_loss': 0.46535250544548035, 'valid_acc': 0.921875}.
# valid Epoch 0 :  41%|████      | 30/74 [00:02<00:03, 14.62batch/s, acc=0.00605, loss=0.22] wandb: WARNING Step must only increase in log calls.  Step 31 < 221; dropping {'valid_loss': 0.4760935604572296, 'valid_acc': 0.90625}.
# valid Epoch 0 :  43%|████▎     | 32/74 [00:02<00:02, 14.89batch/s, acc=0.00624, loss=0.227]wandb: WARNING Step must only increase in log calls.  Step 32 < 221; dropping {'valid_loss': 0.4900815188884735, 'valid_acc': 0.875}.
# valid Epoch 0 :  43%|████▎     | 32/74 [00:03<00:02, 14.89batch/s, acc=0.00642, loss=0.234]wandb: WARNING Step must only increase in log calls.  Step 33 < 221; dropping {'valid_loss': 0.4920791685581207, 'valid_acc': 0.875}.
# valid Epoch 0 :  46%|████▌     | 34/74 [00:03<00:02, 15.49batch/s, acc=0.00661, loss=0.241]wandb: WARNING Step must only increase in log calls.  Step 34 < 221; dropping {'valid_loss': 0.5607070922851562, 'valid_acc': 0.890625}.
# valid Epoch 0 :  46%|████▌     | 34/74 [00:03<00:02, 15.49batch/s, acc=0.00681, loss=0.246]wandb: WARNING Step must only increase in log calls.  Step 35 < 221; dropping {'valid_loss': 0.3723580241203308, 'valid_acc': 0.921875}.
# valid Epoch 0 :  49%|████▊     | 36/74 [00:03<00:02, 15.32batch/s, acc=0.007, loss=0.252]  wandb: WARNING Step must only increase in log calls.  Step 36 < 221; dropping {'valid_loss': 0.40161794424057007, 'valid_acc': 0.921875}.
# valid Epoch 0 :  49%|████▊     | 36/74 [00:03<00:02, 15.32batch/s, acc=0.00719, loss=0.257]wandb: WARNING Step must only increase in log calls.  Step 37 < 221; dropping {'valid_loss': 0.4252163767814636, 'valid_acc': 0.90625}.
# valid Epoch 0 :  51%|█████▏    | 38/74 [00:03<00:02, 16.06batch/s, acc=0.00739, loss=0.264]wandb: WARNING Step must only increase in log calls.  Step 38 < 221; dropping {'valid_loss': 0.4815714657306671, 'valid_acc': 0.921875}.
# valid Epoch 0 :  51%|█████▏    | 38/74 [00:03<00:02, 16.06batch/s, acc=0.00757, loss=0.271]wandb: WARNING Step must only increase in log calls.  Step 39 < 221; dropping {'valid_loss': 0.5463056564331055, 'valid_acc': 0.859375}.
# valid Epoch 0 :  54%|█████▍    | 40/74 [00:03<00:02, 15.86batch/s, acc=0.00776, loss=0.278]wandb: WARNING Step must only increase in log calls.  Step 40 < 221; dropping {'valid_loss': 0.5217066407203674, 'valid_acc': 0.90625}.
# valid Epoch 0 :  54%|█████▍    | 40/74 [00:03<00:02, 15.86batch/s, acc=0.00794, loss=0.287]wandb: WARNING Step must only increase in log calls.  Step 41 < 221; dropping {'valid_loss': 0.6109909415245056, 'valid_acc': 0.84375}.
# valid Epoch 0 :  57%|█████▋    | 42/74 [00:03<00:01, 16.58batch/s, acc=0.00813, loss=0.292]wandb: WARNING Step must only increase in log calls.  Step 42 < 221; dropping {'valid_loss': 0.4139692485332489, 'valid_acc': 0.90625}.
# valid Epoch 0 :  57%|█████▋    | 42/74 [00:03<00:01, 16.58batch/s, acc=0.00832, loss=0.299]wandb: WARNING Step must only increase in log calls.  Step 43 < 221; dropping {'valid_loss': 0.5046086311340332, 'valid_acc': 0.90625}.
# valid Epoch 0 :  59%|█████▉    | 44/74 [00:03<00:01, 16.77batch/s, acc=0.00853, loss=0.304]wandb: WARNING Step must only increase in log calls.  Step 44 < 221; dropping {'valid_loss': 0.379285991191864, 'valid_acc': 0.953125}.
# valid Epoch 0 :  59%|█████▉    | 44/74 [00:03<00:01, 16.77batch/s, acc=0.0087, loss=0.312] wandb: WARNING Step must only increase in log calls.  Step 45 < 221; dropping {'valid_loss': 0.5995197892189026, 'valid_acc': 0.8125}.
# valid Epoch 0 :  62%|██████▏   | 46/74 [00:03<00:01, 16.91batch/s, acc=0.00889, loss=0.318]wandb: WARNING Step must only increase in log calls.  Step 46 < 221; dropping {'valid_loss': 0.4454137086868286, 'valid_acc': 0.90625}.
# valid Epoch 0 :  62%|██████▏   | 46/74 [00:03<00:01, 16.91batch/s, acc=0.00907, loss=0.325]wandb: WARNING Step must only increase in log calls.  Step 47 < 221; dropping {'valid_loss': 0.49794691801071167, 'valid_acc': 0.875}.
# valid Epoch 0 :  65%|██████▍   | 48/74 [00:03<00:01, 17.34batch/s, acc=0.00926, loss=0.332]wandb: WARNING Step must only increase in log calls.  Step 48 < 221; dropping {'valid_loss': 0.5297800898551941, 'valid_acc': 0.890625}.
# valid Epoch 0 :  65%|██████▍   | 48/74 [00:03<00:01, 17.34batch/s, acc=0.00946, loss=0.338]wandb: WARNING Step must only increase in log calls.  Step 49 < 221; dropping {'valid_loss': 0.42293956875801086, 'valid_acc': 0.9375}.
# valid Epoch 0 :  68%|██████▊   | 50/74 [00:04<00:01, 15.98batch/s, acc=0.00965, loss=0.344]wandb: WARNING Step must only increase in log calls.  Step 50 < 221; dropping {'valid_loss': 0.44895341992378235, 'valid_acc': 0.890625}.
# valid Epoch 0 :  68%|██████▊   | 50/74 [00:04<00:01, 15.98batch/s, acc=0.00985, loss=0.35] wandb: WARNING Step must only increase in log calls.  Step 51 < 221; dropping {'valid_loss': 0.40485960245132446, 'valid_acc': 0.9375}.
# valid Epoch 0 :  70%|███████   | 52/74 [00:04<00:01, 15.77batch/s, acc=0.01, loss=0.357]  wandb: WARNING Step must only increase in log calls.  Step 52 < 221; dropping {'valid_loss': 0.5513334274291992, 'valid_acc': 0.90625}.
# valid Epoch 0 :  70%|███████   | 52/74 [00:04<00:01, 15.77batch/s, acc=0.0102, loss=0.363]wandb: WARNING Step must only increase in log calls.  Step 53 < 221; dropping {'valid_loss': 0.4428938329219818, 'valid_acc': 0.90625}.
# valid Epoch 0 :  73%|███████▎  | 54/74 [00:04<00:01, 16.48batch/s, acc=0.0104, loss=0.37] wandb: WARNING Step must only increase in log calls.  Step 54 < 221; dropping {'valid_loss': 0.5191685557365417, 'valid_acc': 0.890625}.
# valid Epoch 0 :  73%|███████▎  | 54/74 [00:04<00:01, 16.48batch/s, acc=0.0106, loss=0.379]wandb: WARNING Step must only increase in log calls.  Step 55 < 221; dropping {'valid_loss': 0.6752362847328186, 'valid_acc': 0.84375}.
# valid Epoch 0 :  76%|███████▌  | 56/74 [00:04<00:01, 17.06batch/s, acc=0.0108, loss=0.387]wandb: WARNING Step must only increase in log calls.  Step 56 < 221; dropping {'valid_loss': 0.5839052796363831, 'valid_acc': 0.90625}.
# valid Epoch 0 :  76%|███████▌  | 56/74 [00:04<00:01, 17.06batch/s, acc=0.011, loss=0.396] wandb: WARNING Step must only increase in log calls.  Step 57 < 221; dropping {'valid_loss': 0.6502106785774231, 'valid_acc': 0.84375}.
# valid Epoch 0 :  78%|███████▊  | 58/74 [00:04<00:00, 16.70batch/s, acc=0.0112, loss=0.401]wandb: WARNING Step must only increase in log calls.  Step 58 < 221; dropping {'valid_loss': 0.4024040699005127, 'valid_acc': 0.890625}.
# valid Epoch 0 :  78%|███████▊  | 58/74 [00:04<00:00, 16.70batch/s, acc=0.0113, loss=0.408]wandb: WARNING Step must only increase in log calls.  Step 59 < 221; dropping {'valid_loss': 0.5215955376625061, 'valid_acc': 0.859375}.
# valid Epoch 0 :  81%|████████  | 60/74 [00:04<00:00, 17.20batch/s, acc=0.0115, loss=0.417]wandb: WARNING Step must only increase in log calls.  Step 60 < 221; dropping {'valid_loss': 0.6521716713905334, 'valid_acc': 0.796875}.
# valid Epoch 0 :  81%|████████  | 60/74 [00:04<00:00, 17.20batch/s, acc=0.0117, loss=0.425]wandb: WARNING Step must only increase in log calls.  Step 61 < 221; dropping {'valid_loss': 0.5500305891036987, 'valid_acc': 0.875}.
# valid Epoch 0 :  84%|████████▍ | 62/74 [00:04<00:00, 17.55batch/s, acc=0.0119, loss=0.431]wandb: WARNING Step must only increase in log calls.  Step 62 < 221; dropping {'valid_loss': 0.43135571479797363, 'valid_acc': 0.90625}.
# valid Epoch 0 :  84%|████████▍ | 62/74 [00:04<00:00, 17.55batch/s, acc=0.0121, loss=0.438]wandb: WARNING Step must only increase in log calls.  Step 63 < 221; dropping {'valid_loss': 0.5357787013053894, 'valid_acc': 0.875}.
# valid Epoch 0 :  86%|████████▋ | 64/74 [00:04<00:00, 17.67batch/s, acc=0.0123, loss=0.443]wandb: WARNING Step must only increase in log calls.  Step 64 < 221; dropping {'valid_loss': 0.3423680365085602, 'valid_acc': 0.953125}.
# valid Epoch 0 :  86%|████████▋ | 64/74 [00:04<00:00, 17.67batch/s, acc=0.0125, loss=0.451]wandb: WARNING Step must only increase in log calls.  Step 65 < 221; dropping {'valid_loss': 0.6141429543495178, 'valid_acc': 0.84375}.
# valid Epoch 0 :  89%|████████▉ | 66/74 [00:04<00:00, 17.86batch/s, acc=0.0126, loss=0.458]wandb: WARNING Step must only increase in log calls.  Step 66 < 221; dropping {'valid_loss': 0.5288335084915161, 'valid_acc': 0.859375}.
# valid Epoch 0 :  89%|████████▉ | 66/74 [00:04<00:00, 17.86batch/s, acc=0.0128, loss=0.464]wandb: WARNING Step must only increase in log calls.  Step 67 < 221; dropping {'valid_loss': 0.44764837622642517, 'valid_acc': 0.890625}.
# valid Epoch 0 :  92%|█████████▏| 68/74 [00:05<00:00, 18.03batch/s, acc=0.013, loss=0.473] wandb: WARNING Step must only increase in log calls.  Step 68 < 221; dropping {'valid_loss': 0.6838936805725098, 'valid_acc': 0.859375}.
# valid Epoch 0 :  92%|█████████▏| 68/74 [00:05<00:00, 18.03batch/s, acc=0.0132, loss=0.479]wandb: WARNING Step must only increase in log calls.  Step 69 < 221; dropping {'valid_loss': 0.4463401734828949, 'valid_acc': 0.921875}.
# valid Epoch 0 :  95%|█████████▍| 70/74 [00:05<00:00, 18.23batch/s, acc=0.0134, loss=0.486]wandb: WARNING Step must only increase in log calls.  Step 70 < 221; dropping {'valid_loss': 0.46402013301849365, 'valid_acc': 0.90625}.
# valid Epoch 0 :  95%|█████████▍| 70/74 [00:05<00:00, 18.23batch/s, acc=0.0136, loss=0.492]wandb: WARNING Step must only increase in log calls.  Step 71 < 221; dropping {'valid_loss': 0.48521071672439575, 'valid_acc': 0.921875}.
# valid Epoch 0 :  97%|█████████▋| 72/74 [00:05<00:00, 18.41batch/s, acc=0.0138, loss=0.5]  wandb: WARNING Step must only increase in log calls.  Step 72 < 221; dropping {'valid_loss': 0.5528479218482971, 'valid_acc': 0.90625}.
# valid Epoch 0 :  97%|█████████▋| 72/74 [00:05<00:00, 18.41batch/s, acc=0.014, loss=0.504]wandb: WARNING Step must only increase in log calls.  Step 73 < 221; dropping {'valid_loss': 0.40241488814353943, 'valid_acc': 0.9433962264150944}.
# valid Epoch 0 : 100%|██████████| 74/74 [00:05<00:00, 13.71batch/s, acc=0.014, loss=0.504]
# train Epoch 1 : 100%|██████████| 222/222 [01:11<00:00,  3.12batch/s, acc=0.0136, loss=0.492]
# valid Epoch 1 :   0%|          | 0/74 [00:00<?, ?batch/s, acc=0.000195, loss=0.00452]wandb: WARNING Step must only increase in log calls.  Step 74 < 443; dropping {'valid_loss': 0.3336542844772339, 'valid_acc': 0.921875}.
# valid Epoch 1 :   1%|▏         | 1/74 [00:00<00:54,  1.35batch/s, acc=0.000374, loss=0.00943]wandb: WARNING Step must only increase in log calls.  Step 75 < 443; dropping {'valid_loss': 0.36273807287216187, 'valid_acc': 0.84375}.
# valid Epoch 1 :   1%|▏         | 1/74 [00:00<00:54,  1.35batch/s, acc=0.000569, loss=0.0132] wandb: WARNING Step must only increase in log calls.  Step 76 < 443; dropping {'valid_loss': 0.28139352798461914, 'valid_acc': 0.921875}.
# valid Epoch 1 :   4%|▍         | 3/74 [00:00<00:38,  1.83batch/s, acc=0.000771, loss=0.0164]wandb: WARNING Step must only increase in log calls.  Step 77 < 443; dropping {'valid_loss': 0.2326783835887909, 'valid_acc': 0.953125}.
# valid Epoch 1 :   4%|▍         | 3/74 [00:01<00:38,  1.83batch/s, acc=0.000956, loss=0.0209]wandb: WARNING Step must only increase in log calls.  Step 78 < 443; dropping {'valid_loss': 0.33576828241348267, 'valid_acc': 0.875}.
# valid Epoch 1 :   7%|▋         | 5/74 [00:01<00:27,  2.48batch/s, acc=0.00116, loss=0.0237] wandb: WARNING Step must only increase in log calls.  Step 79 < 443; dropping {'valid_loss': 0.2049056738615036, 'valid_acc': 0.953125}.
# valid Epoch 1 :   7%|▋         | 5/74 [00:01<00:27,  2.48batch/s, acc=0.00136, loss=0.0277]wandb: WARNING Step must only increase in log calls.  Step 80 < 443; dropping {'valid_loss': 0.29418256878852844, 'valid_acc': 0.9375}.
# valid Epoch 1 :   9%|▉         | 7/74 [00:01<00:20,  3.33batch/s, acc=0.00155, loss=0.0307]wandb: WARNING Step must only increase in log calls.  Step 81 < 443; dropping {'valid_loss': 0.21903112530708313, 'valid_acc': 0.921875}.
# valid Epoch 1 :   9%|▉         | 7/74 [00:01<00:20,  3.33batch/s, acc=0.00174, loss=0.0345]wandb: WARNING Step must only increase in log calls.  Step 82 < 443; dropping {'valid_loss': 0.2796829342842102, 'valid_acc': 0.90625}.
# valid Epoch 1 :  12%|█▏        | 9/74 [00:01<00:14,  4.35batch/s, acc=0.00193, loss=0.0388]wandb: WARNING Step must only increase in log calls.  Step 83 < 443; dropping {'valid_loss': 0.31690657138824463, 'valid_acc': 0.875}.
# valid Epoch 1 :  12%|█▏        | 9/74 [00:01<00:14,  4.35batch/s, acc=0.00213, loss=0.0415]wandb: WARNING Step must only increase in log calls.  Step 84 < 443; dropping {'valid_loss': 0.20108790695667267, 'valid_acc': 0.953125}.
# valid Epoch 1 :  15%|█▍        | 11/74 [00:01<00:11,  5.64batch/s, acc=0.00233, loss=0.0443]wandb: WARNING Step must only increase in log calls.  Step 85 < 443; dropping {'valid_loss': 0.21221035718917847, 'valid_acc': 0.9375}.
# valid Epoch 1 :  15%|█▍        | 11/74 [00:01<00:11,  5.64batch/s, acc=0.00253, loss=0.0481]wandb: WARNING Step must only increase in log calls.  Step 86 < 443; dropping {'valid_loss': 0.279398649930954, 'valid_acc': 0.9375}.
# valid Epoch 1 :  18%|█▊        | 13/74 [00:01<00:08,  7.00batch/s, acc=0.00272, loss=0.0509]wandb: WARNING Step must only increase in log calls.  Step 87 < 443; dropping {'valid_loss': 0.20397554337978363, 'valid_acc': 0.9375}.
# valid Epoch 1 :  18%|█▊        | 13/74 [00:01<00:08,  7.00batch/s, acc=0.00292, loss=0.0544]wandb: WARNING Step must only increase in log calls.  Step 88 < 443; dropping {'valid_loss': 0.2608063220977783, 'valid_acc': 0.90625}.
# valid Epoch 1 :  20%|██        | 15/74 [00:01<00:07,  8.30batch/s, acc=0.00312, loss=0.057] wandb: WARNING Step must only increase in log calls.  Step 89 < 443; dropping {'valid_loss': 0.19162924587726593, 'valid_acc': 0.96875}.
# valid Epoch 1 :  20%|██        | 15/74 [00:01<00:07,  8.30batch/s, acc=0.00331, loss=0.0616]wandb: WARNING Step must only increase in log calls.  Step 90 < 443; dropping {'valid_loss': 0.33950769901275635, 'valid_acc': 0.90625}.
# valid Epoch 1 :  23%|██▎       | 17/74 [00:01<00:05,  9.89batch/s, acc=0.00351, loss=0.0642]wandb: WARNING Step must only increase in log calls.  Step 91 < 443; dropping {'valid_loss': 0.1869177371263504, 'valid_acc': 0.90625}.
# valid Epoch 1 :  23%|██▎       | 17/74 [00:01<00:05,  9.89batch/s, acc=0.0037, loss=0.0672] wandb: WARNING Step must only increase in log calls.  Step 92 < 443; dropping {'valid_loss': 0.2264186441898346, 'valid_acc': 0.90625}.
# valid Epoch 1 :  26%|██▌       | 19/74 [00:02<00:05, 10.76batch/s, acc=0.0039, loss=0.0696]wandb: WARNING Step must only increase in log calls.  Step 93 < 443; dropping {'valid_loss': 0.17385199666023254, 'valid_acc': 0.9375}.
# valid Epoch 1 :  26%|██▌       | 19/74 [00:02<00:05, 10.76batch/s, acc=0.00409, loss=0.0726]wandb: WARNING Step must only increase in log calls.  Step 94 < 443; dropping {'valid_loss': 0.2238394320011139, 'valid_acc': 0.9375}.
# valid Epoch 1 :  28%|██▊       | 21/74 [00:02<00:04, 11.93batch/s, acc=0.00429, loss=0.0758]wandb: WARNING Step must only increase in log calls.  Step 95 < 443; dropping {'valid_loss': 0.23867355287075043, 'valid_acc': 0.921875}.
# valid Epoch 1 :  28%|██▊       | 21/74 [00:02<00:04, 11.93batch/s, acc=0.00449, loss=0.0796]wandb: WARNING Step must only increase in log calls.  Step 96 < 443; dropping {'valid_loss': 0.2789703905582428, 'valid_acc': 0.9375}.
# valid Epoch 1 :  31%|███       | 23/74 [00:02<00:03, 13.36batch/s, acc=0.00469, loss=0.0821]wandb: WARNING Step must only increase in log calls.  Step 97 < 443; dropping {'valid_loss': 0.18054819107055664, 'valid_acc': 0.953125}.
# valid Epoch 1 :  31%|███       | 23/74 [00:02<00:03, 13.36batch/s, acc=0.00488, loss=0.0873]wandb: WARNING Step must only increase in log calls.  Step 98 < 443; dropping {'valid_loss': 0.38855183124542236, 'valid_acc': 0.90625}.
# valid Epoch 1 :  34%|███▍      | 25/74 [00:02<00:03, 14.25batch/s, acc=0.00506, loss=0.0936]wandb: WARNING Step must only increase in log calls.  Step 99 < 443; dropping {'valid_loss': 0.463784396648407, 'valid_acc': 0.84375}.
# valid Epoch 1 :  34%|███▍      | 25/74 [00:02<00:03, 14.25batch/s, acc=0.00525, loss=0.0977]wandb: WARNING Step must only increase in log calls.  Step 100 < 443; dropping {'valid_loss': 0.2992086708545685, 'valid_acc': 0.890625}.
# valid Epoch 1 :  36%|███▋      | 27/74 [00:02<00:03, 14.64batch/s, acc=0.00544, loss=0.103] wandb: WARNING Step must only increase in log calls.  Step 101 < 443; dropping {'valid_loss': 0.3766331970691681, 'valid_acc': 0.90625}.
# valid Epoch 1 :  36%|███▋      | 27/74 [00:02<00:03, 14.64batch/s, acc=0.00564, loss=0.106]wandb: WARNING Step must only increase in log calls.  Step 102 < 443; dropping {'valid_loss': 0.2501334846019745, 'valid_acc': 0.953125}.
# valid Epoch 1 :  39%|███▉      | 29/74 [00:02<00:02, 15.23batch/s, acc=0.00585, loss=0.108]wandb: WARNING Step must only increase in log calls.  Step 103 < 443; dropping {'valid_loss': 0.14547310769557953, 'valid_acc': 0.96875}.
# valid Epoch 1 :  39%|███▉      | 29/74 [00:02<00:02, 15.23batch/s, acc=0.00604, loss=0.111]wandb: WARNING Step must only increase in log calls.  Step 104 < 443; dropping {'valid_loss': 0.23663905262947083, 'valid_acc': 0.9375}.
# valid Epoch 1 :  42%|████▏     | 31/74 [00:02<00:02, 15.94batch/s, acc=0.00624, loss=0.114]wandb: WARNING Step must only increase in log calls.  Step 105 < 443; dropping {'valid_loss': 0.21473756432533264, 'valid_acc': 0.9375}.
# valid Epoch 1 :  42%|████▏     | 31/74 [00:02<00:02, 15.94batch/s, acc=0.00644, loss=0.118]wandb: WARNING Step must only increase in log calls.  Step 106 < 443; dropping {'valid_loss': 0.2893979549407959, 'valid_acc': 0.90625}.
# valid Epoch 1 :  45%|████▍     | 33/74 [00:02<00:02, 16.61batch/s, acc=0.00663, loss=0.122]wandb: WARNING Step must only increase in log calls.  Step 107 < 443; dropping {'valid_loss': 0.28122153878211975, 'valid_acc': 0.90625}.
# valid Epoch 1 :  45%|████▍     | 33/74 [00:02<00:02, 16.61batch/s, acc=0.00682, loss=0.125]wandb: WARNING Step must only increase in log calls.  Step 108 < 443; dropping {'valid_loss': 0.24840694665908813, 'valid_acc': 0.890625}.
# valid Epoch 1 :  47%|████▋     | 35/74 [00:02<00:02, 16.75batch/s, acc=0.00701, loss=0.128]wandb: WARNING Step must only increase in log calls.  Step 109 < 443; dropping {'valid_loss': 0.1708718240261078, 'valid_acc': 0.9375}.
# valid Epoch 1 :  47%|████▋     | 35/74 [00:02<00:02, 16.75batch/s, acc=0.00722, loss=0.13] wandb: WARNING Step must only increase in log calls.  Step 110 < 443; dropping {'valid_loss': 0.16474126279354095, 'valid_acc': 0.96875}.
# valid Epoch 1 :  50%|█████     | 37/74 [00:03<00:02, 16.90batch/s, acc=0.00742, loss=0.133]wandb: WARNING Step must only increase in log calls.  Step 111 < 443; dropping {'valid_loss': 0.21586892008781433, 'valid_acc': 0.9375}.
# valid Epoch 1 :  50%|█████     | 37/74 [00:03<00:02, 16.90batch/s, acc=0.00762, loss=0.135]wandb: WARNING Step must only increase in log calls.  Step 112 < 443; dropping {'valid_loss': 0.16847342252731323, 'valid_acc': 0.96875}.
# valid Epoch 1 :  53%|█████▎    | 39/74 [00:03<00:02, 11.83batch/s, acc=0.00781, loss=0.139]wandb: WARNING Step must only increase in log calls.  Step 113 < 443; dropping {'valid_loss': 0.30758246779441833, 'valid_acc': 0.90625}.
# valid Epoch 1 :  53%|█████▎    | 39/74 [00:03<00:02, 11.83batch/s, acc=0.00801, loss=0.143]wandb: WARNING Step must only increase in log calls.  Step 114 < 443; dropping {'valid_loss': 0.27345001697540283, 'valid_acc': 0.9375}.
# valid Epoch 1 :  55%|█████▌    | 41/74 [00:03<00:02, 13.27batch/s, acc=0.0082, loss=0.147] wandb: WARNING Step must only increase in log calls.  Step 115 < 443; dropping {'valid_loss': 0.31138351559638977, 'valid_acc': 0.90625}.
# valid Epoch 1 :  55%|█████▌    | 41/74 [00:03<00:02, 13.27batch/s, acc=0.00841, loss=0.149]wandb: WARNING Step must only increase in log calls.  Step 116 < 443; dropping {'valid_loss': 0.15207798779010773, 'valid_acc': 0.984375}.
# valid Epoch 1 :  58%|█████▊    | 43/74 [00:03<00:02, 14.50batch/s, acc=0.00861, loss=0.153]wandb: WARNING Step must only increase in log calls.  Step 117 < 443; dropping {'valid_loss': 0.24919793009757996, 'valid_acc': 0.921875}.
# valid Epoch 1 :  58%|█████▊    | 43/74 [00:03<00:02, 14.50batch/s, acc=0.00881, loss=0.155]wandb: WARNING Step must only increase in log calls.  Step 118 < 443; dropping {'valid_loss': 0.16135354340076447, 'valid_acc': 0.96875}.
# valid Epoch 1 :  61%|██████    | 45/74 [00:03<00:01, 15.36batch/s, acc=0.00901, loss=0.159]wandb: WARNING Step must only increase in log calls.  Step 119 < 443; dropping {'valid_loss': 0.30728843808174133, 'valid_acc': 0.921875}.
# valid Epoch 1 :  61%|██████    | 45/74 [00:03<00:01, 15.36batch/s, acc=0.00921, loss=0.163]wandb: WARNING Step must only increase in log calls.  Step 120 < 443; dropping {'valid_loss': 0.2807624936103821, 'valid_acc': 0.9375}.
# valid Epoch 1 :  64%|██████▎   | 47/74 [00:03<00:01, 13.93batch/s, acc=0.00941, loss=0.166]wandb: WARNING Step must only increase in log calls.  Step 121 < 443; dropping {'valid_loss': 0.22422175109386444, 'valid_acc': 0.96875}.
# valid Epoch 1 :  64%|██████▎   | 47/74 [00:03<00:01, 13.93batch/s, acc=0.00961, loss=0.17] wandb: WARNING Step must only increase in log calls.  Step 122 < 443; dropping {'valid_loss': 0.3131393492221832, 'valid_acc': 0.9375}.
# valid Epoch 1 :  66%|██████▌   | 49/74 [00:03<00:01, 13.96batch/s, acc=0.00981, loss=0.172]wandb: WARNING Step must only increase in log calls.  Step 123 < 443; dropping {'valid_loss': 0.16745369136333466, 'valid_acc': 0.96875}.
# valid Epoch 1 :  66%|██████▌   | 49/74 [00:04<00:01, 13.96batch/s, acc=0.01, loss=0.175]   wandb: WARNING Step must only increase in log calls.  Step 124 < 443; dropping {'valid_loss': 0.22777624428272247, 'valid_acc': 0.953125}.
# valid Epoch 1 :  69%|██████▉   | 51/74 [00:04<00:01, 14.66batch/s, acc=0.0102, loss=0.178]wandb: WARNING Step must only increase in log calls.  Step 125 < 443; dropping {'valid_loss': 0.21632477641105652, 'valid_acc': 0.9375}.
# valid Epoch 1 :  69%|██████▉   | 51/74 [00:04<00:01, 14.66batch/s, acc=0.0104, loss=0.182]wandb: WARNING Step must only increase in log calls.  Step 126 < 443; dropping {'valid_loss': 0.30785587430000305, 'valid_acc': 0.90625}.
# valid Epoch 1 :  72%|███████▏  | 53/74 [00:04<00:01, 15.68batch/s, acc=0.0106, loss=0.185]wandb: WARNING Step must only increase in log calls.  Step 127 < 443; dropping {'valid_loss': 0.19241909682750702, 'valid_acc': 0.9375}.
# valid Epoch 1 :  72%|███████▏  | 53/74 [00:04<00:01, 15.68batch/s, acc=0.0108, loss=0.19] wandb: WARNING Step must only increase in log calls.  Step 128 < 443; dropping {'valid_loss': 0.33440306782722473, 'valid_acc': 0.921875}.
# valid Epoch 1 :  74%|███████▍  | 55/74 [00:04<00:01, 15.45batch/s, acc=0.011, loss=0.196]wandb: WARNING Step must only increase in log calls.  Step 129 < 443; dropping {'valid_loss': 0.43671947717666626, 'valid_acc': 0.875}.
# valid Epoch 1 :  74%|███████▍  | 55/74 [00:04<00:01, 15.45batch/s, acc=0.0112, loss=0.2] wandb: WARNING Step must only increase in log calls.  Step 130 < 443; dropping {'valid_loss': 0.3342662453651428, 'valid_acc': 0.9375}.
# valid Epoch 1 :  77%|███████▋  | 57/74 [00:04<00:01, 16.14batch/s, acc=0.0114, loss=0.206]wandb: WARNING Step must only increase in log calls.  Step 131 < 443; dropping {'valid_loss': 0.4212460219860077, 'valid_acc': 0.90625}.
# valid Epoch 1 :  77%|███████▋  | 57/74 [00:04<00:01, 16.14batch/s, acc=0.0116, loss=0.209]wandb: WARNING Step must only increase in log calls.  Step 132 < 443; dropping {'valid_loss': 0.20212604105472565, 'valid_acc': 0.96875}.
# valid Epoch 1 :  80%|███████▉  | 59/74 [00:04<00:00, 16.67batch/s, acc=0.0118, loss=0.212]wandb: WARNING Step must only increase in log calls.  Step 133 < 443; dropping {'valid_loss': 0.2515813708305359, 'valid_acc': 0.875}.
# valid Epoch 1 :  80%|███████▉  | 59/74 [00:04<00:00, 16.67batch/s, acc=0.012, loss=0.216] wandb: WARNING Step must only increase in log calls.  Step 134 < 443; dropping {'valid_loss': 0.30857038497924805, 'valid_acc': 0.90625}.
# valid Epoch 1 :  82%|████████▏ | 61/74 [00:04<00:00, 16.73batch/s, acc=0.0122, loss=0.219]wandb: WARNING Step must only increase in log calls.  Step 135 < 443; dropping {'valid_loss': 0.2385931760072708, 'valid_acc': 0.921875}.
# valid Epoch 1 :  82%|████████▏ | 61/74 [00:04<00:00, 16.73batch/s, acc=0.0123, loss=0.223]wandb: WARNING Step must only increase in log calls.  Step 136 < 443; dropping {'valid_loss': 0.27122437953948975, 'valid_acc': 0.921875}.
# valid Epoch 1 :  85%|████████▌ | 63/74 [00:04<00:00, 17.22batch/s, acc=0.0125, loss=0.228]wandb: WARNING Step must only increase in log calls.  Step 137 < 443; dropping {'valid_loss': 0.37421542406082153, 'valid_acc': 0.921875}.
# valid Epoch 1 :  85%|████████▌ | 63/74 [00:04<00:00, 17.22batch/s, acc=0.0127, loss=0.23] wandb: WARNING Step must only increase in log calls.  Step 138 < 443; dropping {'valid_loss': 0.15546710789203644, 'valid_acc': 0.953125}.
# valid Epoch 1 :  88%|████████▊ | 65/74 [00:04<00:00, 17.61batch/s, acc=0.0129, loss=0.234]wandb: WARNING Step must only increase in log calls.  Step 139 < 443; dropping {'valid_loss': 0.31242460012435913, 'valid_acc': 0.9375}.
# valid Epoch 1 :  88%|████████▊ | 65/74 [00:04<00:00, 17.61batch/s, acc=0.0131, loss=0.238]wandb: WARNING Step must only increase in log calls.  Step 140 < 443; dropping {'valid_loss': 0.26000216603279114, 'valid_acc': 0.90625}.
# valid Epoch 1 :  91%|█████████ | 67/74 [00:04<00:00, 17.92batch/s, acc=0.0133, loss=0.24] wandb: WARNING Step must only increase in log calls.  Step 141 < 443; dropping {'valid_loss': 0.18414634466171265, 'valid_acc': 0.9375}.
# valid Epoch 1 :  91%|█████████ | 67/74 [00:05<00:00, 17.92batch/s, acc=0.0135, loss=0.245]wandb: WARNING Step must only increase in log calls.  Step 142 < 443; dropping {'valid_loss': 0.3340463638305664, 'valid_acc': 0.90625}.
# valid Epoch 1 :  93%|█████████▎| 69/74 [00:05<00:00, 18.18batch/s, acc=0.0137, loss=0.248]wandb: WARNING Step must only increase in log calls.  Step 143 < 443; dropping {'valid_loss': 0.21400654315948486, 'valid_acc': 0.96875}.
# valid Epoch 1 :  93%|█████████▎| 69/74 [00:05<00:00, 18.18batch/s, acc=0.0139, loss=0.252]wandb: WARNING Step must only increase in log calls.  Step 144 < 443; dropping {'valid_loss': 0.27584996819496155, 'valid_acc': 0.90625}.
# valid Epoch 1 :  96%|█████████▌| 71/74 [00:05<00:00, 18.34batch/s, acc=0.0141, loss=0.255]wandb: WARNING Step must only increase in log calls.  Step 145 < 443; dropping {'valid_loss': 0.24204358458518982, 'valid_acc': 0.921875}.
# valid Epoch 1 :  96%|█████████▌| 71/74 [00:05<00:00, 18.34batch/s, acc=0.0143, loss=0.258]wandb: WARNING Step must only increase in log calls.  Step 146 < 443; dropping {'valid_loss': 0.266234427690506, 'valid_acc': 0.921875}.
# valid Epoch 1 :  99%|█████████▊| 73/74 [00:05<00:00, 17.74batch/s, acc=0.0145, loss=0.26] wandb: WARNING Step must only increase in log calls.  Step 147 < 443; dropping {'valid_loss': 0.17053177952766418, 'valid_acc': 0.9622641509433962}.
# valid Epoch 1 : 100%|██████████| 74/74 [00:05<00:00, 13.65batch/s, acc=0.0145, loss=0.26]
# train Epoch 2 : 100%|██████████| 222/222 [01:13<00:00,  3.02batch/s, acc=0.0141, loss=0.309]
# valid Epoch 2 :   0%|          | 0/74 [00:00<?, ?batch/s, acc=0.000195, loss=0.00293]wandb: WARNING Step must only increase in log calls.  Step 148 < 665; dropping {'valid_loss': 0.21597513556480408, 'valid_acc': 0.921875}.
# valid Epoch 2 :   1%|▏         | 1/74 [00:00<00:58,  1.24batch/s, acc=0.000384, loss=0.00591]wandb: WARNING Step must only increase in log calls.  Step 149 < 665; dropping {'valid_loss': 0.22064708173274994, 'valid_acc': 0.890625}.
# valid Epoch 2 :   1%|▏         | 1/74 [00:00<00:58,  1.24batch/s, acc=0.000582, loss=0.00872]wandb: WARNING Step must only increase in log calls.  Step 150 < 665; dropping {'valid_loss': 0.20735731720924377, 'valid_acc': 0.9375}.
# valid Epoch 2 :   4%|▍         | 3/74 [00:00<00:41,  1.71batch/s, acc=0.000784, loss=0.0107] wandb: WARNING Step must only increase in log calls.  Step 151 < 665; dropping {'valid_loss': 0.14783364534378052, 'valid_acc': 0.953125}.
# valid Epoch 2 :   4%|▍         | 3/74 [00:01<00:41,  1.71batch/s, acc=0.000972, loss=0.0144]wandb: WARNING Step must only increase in log calls.  Step 152 < 665; dropping {'valid_loss': 0.26770418882369995, 'valid_acc': 0.890625}.
# valid Epoch 2 :   7%|▋         | 5/74 [00:01<00:29,  2.34batch/s, acc=0.00117, loss=0.0168] wandb: WARNING Step must only increase in log calls.  Step 153 < 665; dropping {'valid_loss': 0.18397162854671478, 'valid_acc': 0.953125}.
# valid Epoch 2 :   7%|▋         | 5/74 [00:01<00:29,  2.34batch/s, acc=0.00138, loss=0.0196]wandb: WARNING Step must only increase in log calls.  Step 154 < 665; dropping {'valid_loss': 0.20313815772533417, 'valid_acc': 0.953125}.
# valid Epoch 2 :   9%|▉         | 7/74 [00:01<00:21,  3.14batch/s, acc=0.00157, loss=0.0218]wandb: WARNING Step must only increase in log calls.  Step 155 < 665; dropping {'valid_loss': 0.16630157828330994, 'valid_acc': 0.921875}.
# valid Epoch 2 :   9%|▉         | 7/74 [00:01<00:21,  3.14batch/s, acc=0.00176, loss=0.0244]wandb: WARNING Step must only increase in log calls.  Step 156 < 665; dropping {'valid_loss': 0.19207292795181274, 'valid_acc': 0.90625}.
# valid Epoch 2 :  12%|█▏        | 9/74 [00:01<00:15,  4.15batch/s, acc=0.00196, loss=0.0274]wandb: WARNING Step must only increase in log calls.  Step 157 < 665; dropping {'valid_loss': 0.21626818180084229, 'valid_acc': 0.921875}.
# valid Epoch 2 :  12%|█▏        | 9/74 [00:01<00:15,  4.15batch/s, acc=0.00216, loss=0.0292]wandb: WARNING Step must only increase in log calls.  Step 158 < 665; dropping {'valid_loss': 0.13225123286247253, 'valid_acc': 0.953125}.
# valid Epoch 2 :  15%|█▍        | 11/74 [00:01<00:11,  5.40batch/s, acc=0.00236, loss=0.0312]wandb: WARNING Step must only increase in log calls.  Step 159 < 665; dropping {'valid_loss': 0.1504831314086914, 'valid_acc': 0.953125}.
# valid Epoch 2 :  15%|█▍        | 11/74 [00:01<00:11,  5.40batch/s, acc=0.00256, loss=0.0342]wandb: WARNING Step must only increase in log calls.  Step 160 < 665; dropping {'valid_loss': 0.21877343952655792, 'valid_acc': 0.921875}.
# valid Epoch 2 :  18%|█▊        | 13/74 [00:01<00:08,  6.80batch/s, acc=0.00276, loss=0.0364]wandb: WARNING Step must only increase in log calls.  Step 161 < 665; dropping {'valid_loss': 0.1661989688873291, 'valid_acc': 0.953125}.
# valid Epoch 2 :  18%|█▊        | 13/74 [00:01<00:08,  6.80batch/s, acc=0.00296, loss=0.0389]wandb: WARNING Step must only increase in log calls.  Step 162 < 665; dropping {'valid_loss': 0.18017958104610443, 'valid_acc': 0.9375}.
# valid Epoch 2 :  20%|██        | 15/74 [00:01<00:07,  8.05batch/s, acc=0.00316, loss=0.041] wandb: WARNING Step must only increase in log calls.  Step 163 < 665; dropping {'valid_loss': 0.15660563111305237, 'valid_acc': 0.96875}.
# valid Epoch 2 :  20%|██        | 15/74 [00:01<00:07,  8.05batch/s, acc=0.00336, loss=0.0449]wandb: WARNING Step must only increase in log calls.  Step 164 < 665; dropping {'valid_loss': 0.28732991218566895, 'valid_acc': 0.921875}.
# valid Epoch 2 :  23%|██▎       | 17/74 [00:01<00:06,  9.41batch/s, acc=0.00355, loss=0.0468]wandb: WARNING Step must only increase in log calls.  Step 165 < 665; dropping {'valid_loss': 0.14170485734939575, 'valid_acc': 0.9375}.
# valid Epoch 2 :  23%|██▎       | 17/74 [00:01<00:06,  9.41batch/s, acc=0.00375, loss=0.0491]wandb: WARNING Step must only increase in log calls.  Step 166 < 665; dropping {'valid_loss': 0.16734416782855988, 'valid_acc': 0.921875}.
# valid Epoch 2 :  26%|██▌       | 19/74 [00:01<00:05, 10.88batch/s, acc=0.00395, loss=0.0506]wandb: WARNING Step must only increase in log calls.  Step 167 < 665; dropping {'valid_loss': 0.11268490552902222, 'valid_acc': 0.953125}.
# valid Epoch 2 :  26%|██▌       | 19/74 [00:02<00:05, 10.88batch/s, acc=0.00415, loss=0.0528]wandb: WARNING Step must only increase in log calls.  Step 168 < 665; dropping {'valid_loss': 0.16049563884735107, 'valid_acc': 0.9375}.
# valid Epoch 2 :  28%|██▊       | 21/74 [00:02<00:04, 12.43batch/s, acc=0.00436, loss=0.0551]wandb: WARNING Step must only increase in log calls.  Step 169 < 665; dropping {'valid_loss': 0.1699375957250595, 'valid_acc': 0.96875}.
# valid Epoch 2 :  28%|██▊       | 21/74 [00:02<00:04, 12.43batch/s, acc=0.00456, loss=0.0583]wandb: WARNING Step must only increase in log calls.  Step 170 < 665; dropping {'valid_loss': 0.23972947895526886, 'valid_acc': 0.953125}.
# valid Epoch 2 :  31%|███       | 23/74 [00:02<00:03, 13.46batch/s, acc=0.00476, loss=0.0604]wandb: WARNING Step must only increase in log calls.  Step 171 < 665; dropping {'valid_loss': 0.156954824924469, 'valid_acc': 0.953125}.
# valid Epoch 2 :  31%|███       | 23/74 [00:02<00:03, 13.46batch/s, acc=0.00496, loss=0.0639]wandb: WARNING Step must only increase in log calls.  Step 172 < 665; dropping {'valid_loss': 0.2538754940032959, 'valid_acc': 0.9375}.
# valid Epoch 2 :  34%|███▍      | 25/74 [00:02<00:03, 12.79batch/s, acc=0.00514, loss=0.0693]wandb: WARNING Step must only increase in log calls.  Step 173 < 665; dropping {'valid_loss': 0.4006178379058838, 'valid_acc': 0.859375}.
# valid Epoch 2 :  34%|███▍      | 25/74 [00:02<00:03, 12.79batch/s, acc=0.00533, loss=0.0727]wandb: WARNING Step must only increase in log calls.  Step 174 < 665; dropping {'valid_loss': 0.2534084618091583, 'valid_acc': 0.890625}.
# valid Epoch 2 :  36%|███▋      | 27/74 [00:02<00:03, 14.06batch/s, acc=0.00553, loss=0.0771]wandb: WARNING Step must only increase in log calls.  Step 175 < 665; dropping {'valid_loss': 0.31937023997306824, 'valid_acc': 0.9375}.
# valid Epoch 2 :  36%|███▋      | 27/74 [00:02<00:03, 14.06batch/s, acc=0.00572, loss=0.0803]wandb: WARNING Step must only increase in log calls.  Step 176 < 665; dropping {'valid_loss': 0.23845705389976501, 'valid_acc': 0.9375}.
# valid Epoch 2 :  39%|███▉      | 29/74 [00:02<00:03, 13.74batch/s, acc=0.00594, loss=0.0814]wandb: WARNING Step must only increase in log calls.  Step 177 < 665; dropping {'valid_loss': 0.08379502594470978, 'valid_acc': 1.0}.
# valid Epoch 2 :  39%|███▉      | 29/74 [00:02<00:03, 13.74batch/s, acc=0.00613, loss=0.0836]wandb: WARNING Step must only increase in log calls.  Step 178 < 665; dropping {'valid_loss': 0.16324210166931152, 'valid_acc': 0.9375}.
# valid Epoch 2 :  42%|████▏     | 31/74 [00:02<00:02, 14.47batch/s, acc=0.00634, loss=0.0854]wandb: WARNING Step must only increase in log calls.  Step 179 < 665; dropping {'valid_loss': 0.12987035512924194, 'valid_acc': 0.953125}.
# valid Epoch 2 :  42%|████▏     | 31/74 [00:02<00:02, 14.47batch/s, acc=0.00653, loss=0.0887]wandb: WARNING Step must only increase in log calls.  Step 180 < 665; dropping {'valid_loss': 0.24087034165859222, 'valid_acc': 0.9375}.
# valid Epoch 2 :  45%|████▍     | 33/74 [00:02<00:02, 15.46batch/s, acc=0.00674, loss=0.0911]wandb: WARNING Step must only increase in log calls.  Step 181 < 665; dropping {'valid_loss': 0.17740017175674438, 'valid_acc': 0.96875}.
# valid Epoch 2 :  45%|████▍     | 33/74 [00:02<00:02, 15.46batch/s, acc=0.00694, loss=0.093] wandb: WARNING Step must only increase in log calls.  Step 182 < 665; dropping {'valid_loss': 0.14682531356811523, 'valid_acc': 0.9375}.
# valid Epoch 2 :  47%|████▋     | 35/74 [00:03<00:02, 14.11batch/s, acc=0.00714, loss=0.0948]wandb: WARNING Step must only increase in log calls.  Step 183 < 665; dropping {'valid_loss': 0.12989962100982666, 'valid_acc': 0.953125}.
# valid Epoch 2 :  47%|████▋     | 35/74 [00:03<00:02, 14.11batch/s, acc=0.00734, loss=0.0961]wandb: WARNING Step must only increase in log calls.  Step 184 < 665; dropping {'valid_loss': 0.09897107630968094, 'valid_acc': 0.96875}.
# valid Epoch 2 :  50%|█████     | 37/74 [00:03<00:02, 14.08batch/s, acc=0.00755, loss=0.0983]wandb: WARNING Step must only increase in log calls.  Step 185 < 665; dropping {'valid_loss': 0.15756624937057495, 'valid_acc': 0.96875}.
# valid Epoch 2 :  50%|█████     | 37/74 [00:03<00:02, 14.08batch/s, acc=0.00775, loss=0.0996]wandb: WARNING Step must only increase in log calls.  Step 186 < 665; dropping {'valid_loss': 0.09868466109037399, 'valid_acc': 0.96875}.
# valid Epoch 2 :  53%|█████▎    | 39/74 [00:03<00:02, 14.72batch/s, acc=0.00795, loss=0.102] wandb: WARNING Step must only increase in log calls.  Step 187 < 665; dropping {'valid_loss': 0.2117023766040802, 'valid_acc': 0.921875}.
# valid Epoch 2 :  53%|█████▎    | 39/74 [00:03<00:02, 14.72batch/s, acc=0.00815, loss=0.106]wandb: WARNING Step must only increase in log calls.  Step 188 < 665; dropping {'valid_loss': 0.22779637575149536, 'valid_acc': 0.953125}.
# valid Epoch 2 :  55%|█████▌    | 41/74 [00:03<00:02, 15.72batch/s, acc=0.00835, loss=0.109]wandb: WARNING Step must only increase in log calls.  Step 189 < 665; dropping {'valid_loss': 0.21886777877807617, 'valid_acc': 0.9375}.
# valid Epoch 2 :  55%|█████▌    | 41/74 [00:03<00:02, 15.72batch/s, acc=0.00856, loss=0.11] wandb: WARNING Step must only increase in log calls.  Step 190 < 665; dropping {'valid_loss': 0.09500777721405029, 'valid_acc': 1.0}.
# valid Epoch 2 :  58%|█████▊    | 43/74 [00:03<00:01, 15.72batch/s, acc=0.00876, loss=0.112]wandb: WARNING Step must only increase in log calls.  Step 191 < 665; dropping {'valid_loss': 0.16806109249591827, 'valid_acc': 0.9375}.
# valid Epoch 2 :  58%|█████▊    | 43/74 [00:03<00:01, 15.72batch/s, acc=0.00896, loss=0.114]wandb: WARNING Step must only increase in log calls.  Step 192 < 665; dropping {'valid_loss': 0.13105469942092896, 'valid_acc': 0.96875}.
# valid Epoch 2 :  61%|██████    | 45/74 [00:03<00:01, 16.31batch/s, acc=0.00916, loss=0.117]wandb: WARNING Step must only increase in log calls.  Step 193 < 665; dropping {'valid_loss': 0.2016584873199463, 'valid_acc': 0.9375}.
# valid Epoch 2 :  61%|██████    | 45/74 [00:03<00:01, 16.31batch/s, acc=0.00936, loss=0.12] wandb: WARNING Step must only increase in log calls.  Step 194 < 665; dropping {'valid_loss': 0.24074126780033112, 'valid_acc': 0.921875}.
# valid Epoch 2 :  64%|██████▎   | 47/74 [00:03<00:01, 15.93batch/s, acc=0.00956, loss=0.122]wandb: WARNING Step must only increase in log calls.  Step 195 < 665; dropping {'valid_loss': 0.15404245257377625, 'valid_acc': 0.9375}.
# valid Epoch 2 :  64%|██████▎   | 47/74 [00:03<00:01, 15.93batch/s, acc=0.00976, loss=0.125]wandb: WARNING Step must only increase in log calls.  Step 196 < 665; dropping {'valid_loss': 0.2397495061159134, 'valid_acc': 0.96875}.
# valid Epoch 2 :  66%|██████▌   | 49/74 [00:03<00:01, 16.32batch/s, acc=0.00997, loss=0.127]wandb: WARNING Step must only increase in log calls.  Step 197 < 665; dropping {'valid_loss': 0.10478448122739792, 'valid_acc': 0.96875}.
# valid Epoch 2 :  66%|██████▌   | 49/74 [00:03<00:01, 16.32batch/s, acc=0.0102, loss=0.129] wandb: WARNING Step must only increase in log calls.  Step 198 < 665; dropping {'valid_loss': 0.1773912012577057, 'valid_acc': 0.953125}.
# valid Epoch 2 :  69%|██████▉   | 51/74 [00:04<00:01, 16.93batch/s, acc=0.0104, loss=0.132]wandb: WARNING Step must only increase in log calls.  Step 199 < 665; dropping {'valid_loss': 0.185719296336174, 'valid_acc': 0.9375}.
# valid Epoch 2 :  69%|██████▉   | 51/74 [00:04<00:01, 16.93batch/s, acc=0.0106, loss=0.134]wandb: WARNING Step must only increase in log calls.  Step 200 < 665; dropping {'valid_loss': 0.19129200279712677, 'valid_acc': 0.9375}.
# valid Epoch 2 :  72%|███████▏  | 53/74 [00:04<00:01, 16.98batch/s, acc=0.0108, loss=0.136]wandb: WARNING Step must only increase in log calls.  Step 201 < 665; dropping {'valid_loss': 0.1236206591129303, 'valid_acc': 0.96875}.
# valid Epoch 2 :  72%|███████▏  | 53/74 [00:04<00:01, 16.98batch/s, acc=0.011, loss=0.14]  wandb: WARNING Step must only increase in log calls.  Step 202 < 665; dropping {'valid_loss': 0.2962031364440918, 'valid_acc': 0.90625}.
# valid Epoch 2 :  74%|███████▍  | 55/74 [00:04<00:01, 17.45batch/s, acc=0.0111, loss=0.144]wandb: WARNING Step must only increase in log calls.  Step 203 < 665; dropping {'valid_loss': 0.3323747515678406, 'valid_acc': 0.875}.
# valid Epoch 2 :  74%|███████▍  | 55/74 [00:04<00:01, 17.45batch/s, acc=0.0113, loss=0.148]wandb: WARNING Step must only increase in log calls.  Step 204 < 665; dropping {'valid_loss': 0.26199108362197876, 'valid_acc': 0.953125}.
# valid Epoch 2 :  77%|███████▋  | 57/74 [00:04<00:01, 16.86batch/s, acc=0.0115, loss=0.153]wandb: WARNING Step must only increase in log calls.  Step 205 < 665; dropping {'valid_loss': 0.3578660786151886, 'valid_acc': 0.890625}.
# valid Epoch 2 :  77%|███████▋  | 57/74 [00:04<00:01, 16.86batch/s, acc=0.0117, loss=0.154]wandb: WARNING Step must only increase in log calls.  Step 206 < 665; dropping {'valid_loss': 0.13149820268154144, 'valid_acc': 0.96875}.
# valid Epoch 2 :  80%|███████▉  | 59/74 [00:04<00:00, 17.14batch/s, acc=0.0119, loss=0.157]wandb: WARNING Step must only increase in log calls.  Step 207 < 665; dropping {'valid_loss': 0.19618070125579834, 'valid_acc': 0.9375}.
# ...
# valid Epoch 9 :   7%|▋         | 5/74 [00:01<00:30,  2.25batch/s, acc=0.00143, loss=0.0104] wandb: WARNING Step must only increase in log calls.  Step 672 < 2219; dropping {'valid_loss': 0.07265312224626541, 'valid_acc': 0.984375}.
# valid Epoch 9 :   9%|▉         | 7/74 [00:01<00:22,  3.00batch/s, acc=0.00163, loss=0.0112]wandb: WARNING Step must only increase in log calls.  Step 673 < 2219; dropping {'valid_loss': 0.05957166850566864, 'valid_acc': 0.96875}.
# valid Epoch 9 :   9%|▉         | 7/74 [00:01<00:22,  3.00batch/s, acc=0.00184, loss=0.0121]wandb: WARNING Step must only increase in log calls.  Step 674 < 2219; dropping {'valid_loss': 0.06350507587194443, 'valid_acc': 0.984375}.
# valid Epoch 9 :  12%|█▏        | 9/74 [00:01<00:16,  3.99batch/s, acc=0.00205, loss=0.0132]wandb: WARNING Step must only increase in log calls.  Step 675 < 2219; dropping {'valid_loss': 0.085497185587883, 'valid_acc': 0.96875}.
# valid Epoch 9 :  12%|█▏        | 9/74 [00:01<00:16,  3.99batch/s, acc=0.00226, loss=0.0138]wandb: WARNING Step must only increase in log calls.  Step 676 < 2219; dropping {'valid_loss': 0.04545462504029274, 'valid_acc': 1.0}.
# valid Epoch 9 :  15%|█▍        | 11/74 [00:01<00:12,  5.22batch/s, acc=0.00246, loss=0.0147]wandb: WARNING Step must only increase in log calls.  Step 677 < 2219; dropping {'valid_loss': 0.06357642263174057, 'valid_acc': 0.96875}.
# valid Epoch 9 :  15%|█▍        | 11/74 [00:01<00:12,  5.22batch/s, acc=0.00267, loss=0.0158]wandb: WARNING Step must only increase in log calls.  Step 678 < 2219; dropping {'valid_loss': 0.08090166747570038, 'valid_acc': 0.953125}.
# valid Epoch 9 :  18%|█▊        | 13/74 [00:01<00:09,  6.57batch/s, acc=0.00286, loss=0.017] wandb: WARNING Step must only increase in log calls.  Step 679 < 2219; dropping {'valid_loss': 0.08805491030216217, 'valid_acc': 0.9375}.
# valid Epoch 9 :  18%|█▊        | 13/74 [00:01<00:09,  6.57batch/s, acc=0.00307, loss=0.018]wandb: WARNING Step must only increase in log calls.  Step 680 < 2219; dropping {'valid_loss': 0.07690152525901794, 'valid_acc': 0.96875}.
# valid Epoch 9 :  20%|██        | 15/74 [00:01<00:07,  7.87batch/s, acc=0.00327, loss=0.019]wandb: WARNING Step must only increase in log calls.  Step 681 < 2219; dropping {'valid_loss': 0.07295690476894379, 'valid_acc': 0.96875}.
# valid Epoch 9 :  20%|██        | 15/74 [00:01<00:07,  7.87batch/s, acc=0.00347, loss=0.0217]wandb: WARNING Step must only increase in log calls.  Step 682 < 2219; dropping {'valid_loss': 0.19522419571876526, 'valid_acc': 0.9375}.
# valid Epoch 9 :  23%|██▎       | 17/74 [00:01<00:06,  8.90batch/s, acc=0.00368, loss=0.0224]wandb: WARNING Step must only increase in log calls.  Step 683 < 2219; dropping {'valid_loss': 0.057035982608795166, 'valid_acc': 0.96875}.
# valid Epoch 9 :  23%|██▎       | 17/74 [00:01<00:06,  8.90batch/s, acc=0.00389, loss=0.023] wandb: WARNING Step must only increase in log calls.  Step 684 < 2219; dropping {'valid_loss': 0.04314659908413887, 'valid_acc': 0.984375}.
# valid Epoch 9 :  26%|██▌       | 19/74 [00:02<00:05, 10.40batch/s, acc=0.00409, loss=0.0236]wandb: WARNING Step must only increase in log calls.  Step 685 < 2219; dropping {'valid_loss': 0.0433942973613739, 'valid_acc': 0.96875}.
# valid Epoch 9 :  26%|██▌       | 19/74 [00:02<00:05, 10.40batch/s, acc=0.00429, loss=0.0245]wandb: WARNING Step must only increase in log calls.  Step 686 < 2219; dropping {'valid_loss': 0.06756627559661865, 'valid_acc': 0.953125}.
# valid Epoch 9 :  28%|██▊       | 21/74 [00:02<00:04, 11.74batch/s, acc=0.0045, loss=0.0254] wandb: WARNING Step must only increase in log calls.  Step 687 < 2219; dropping {'valid_loss': 0.06078523024916649, 'valid_acc': 0.984375}.
# valid Epoch 9 :  28%|██▊       | 21/74 [00:02<00:04, 11.74batch/s, acc=0.00471, loss=0.0278]wandb: WARNING Step must only increase in log calls.  Step 688 < 2219; dropping {'valid_loss': 0.18322424590587616, 'valid_acc': 0.96875}.
# valid Epoch 9 :  31%|███       | 23/74 [00:02<00:04, 12.71batch/s, acc=0.00491, loss=0.0293]wandb: WARNING Step must only increase in log calls.  Step 689 < 2219; dropping {'valid_loss': 0.10606683045625687, 'valid_acc': 0.953125}.
# valid Epoch 9 :  31%|███       | 23/74 [00:02<00:04, 12.71batch/s, acc=0.00511, loss=0.0319]wandb: WARNING Step must only increase in log calls.  Step 690 < 2219; dropping {'valid_loss': 0.1936343014240265, 'valid_acc': 0.9375}.
# valid Epoch 9 :  34%|███▍      | 25/74 [00:02<00:03, 13.56batch/s, acc=0.0053, loss=0.0355] wandb: WARNING Step must only increase in log calls.  Step 691 < 2219; dropping {'valid_loss': 0.26971039175987244, 'valid_acc': 0.9375}.
# valid Epoch 9 :  34%|███▍      | 25/74 [00:02<00:03, 13.56batch/s, acc=0.0055, loss=0.0376]wandb: WARNING Step must only increase in log calls.  Step 692 < 2219; dropping {'valid_loss': 0.14808422327041626, 'valid_acc': 0.9375}.
# valid Epoch 9 :  36%|███▋      | 27/74 [00:02<00:03, 14.32batch/s, acc=0.0057, loss=0.0414]wandb: WARNING Step must only increase in log calls.  Step 693 < 2219; dropping {'valid_loss': 0.285411536693573, 'valid_acc': 0.9375}.
# valid Epoch 9 :  36%|███▋      | 27/74 [00:02<00:03, 14.32batch/s, acc=0.0059, loss=0.044] wandb: WARNING Step must only increase in log calls.  Step 694 < 2219; dropping {'valid_loss': 0.18857711553573608, 'valid_acc': 0.953125}.
# valid Epoch 9 :  39%|███▉      | 29/74 [00:02<00:03, 14.86batch/s, acc=0.00611, loss=0.0443]wandb: WARNING Step must only increase in log calls.  Step 695 < 2219; dropping {'valid_loss': 0.02491454780101776, 'valid_acc': 1.0}.
# valid Epoch 9 :  39%|███▉      | 29/74 [00:02<00:03, 14.86batch/s, acc=0.00632, loss=0.045] wandb: WARNING Step must only increase in log calls.  Step 696 < 2219; dropping {'valid_loss': 0.050852078944444656, 'valid_acc': 0.984375}.
# valid Epoch 9 :  42%|████▏     | 31/74 [00:02<00:02, 15.24batch/s, acc=0.00653, loss=0.0457]wandb: WARNING Step must only increase in log calls.  Step 697 < 2219; dropping {'valid_loss': 0.053242333233356476, 'valid_acc': 0.96875}.
# valid Epoch 9 :  42%|████▏     | 31/74 [00:02<00:02, 15.24batch/s, acc=0.00674, loss=0.0466]wandb: WARNING Step must only increase in log calls.  Step 698 < 2219; dropping {'valid_loss': 0.06458485871553421, 'valid_acc': 0.984375}.
# valid Epoch 9 :  45%|████▍     | 33/74 [00:02<00:02, 15.50batch/s, acc=0.00694, loss=0.048] wandb: WARNING Step must only increase in log calls.  Step 699 < 2219; dropping {'valid_loss': 0.1013718992471695, 'valid_acc': 0.984375}.
# valid Epoch 9 :  45%|████▍     | 33/74 [00:02<00:02, 15.50batch/s, acc=0.00714, loss=0.0493]wandb: WARNING Step must only increase in log calls.  Step 700 < 2219; dropping {'valid_loss': 0.09884371608495712, 'valid_acc': 0.9375}.
# valid Epoch 9 :  47%|████▋     | 35/74 [00:03<00:02, 16.07batch/s, acc=0.00735, loss=0.0507]wandb: WARNING Step must only increase in log calls.  Step 701 < 2219; dropping {'valid_loss': 0.10163432359695435, 'valid_acc': 0.96875}.
# valid Epoch 9 :  47%|████▋     | 35/74 [00:03<00:02, 16.07batch/s, acc=0.00756, loss=0.051] wandb: WARNING Step must only increase in log calls.  Step 702 < 2219; dropping {'valid_loss': 0.024613911285996437, 'valid_acc': 1.0}.
# valid Epoch 9 :  50%|█████     | 37/74 [00:03<00:02, 16.15batch/s, acc=0.00777, loss=0.0519]wandb: WARNING Step must only increase in log calls.  Step 703 < 2219; dropping {'valid_loss': 0.0684649720788002, 'valid_acc': 0.984375}.
# valid Epoch 9 :  50%|█████     | 37/74 [00:03<00:02, 16.15batch/s, acc=0.00798, loss=0.053] wandb: WARNING Step must only increase in log calls.  Step 704 < 2219; dropping {'valid_loss': 0.07695799320936203, 'valid_acc': 0.984375}.
# valid Epoch 9 :  53%|█████▎    | 39/74 [00:03<00:02, 16.38batch/s, acc=0.00818, loss=0.0542]wandb: WARNING Step must only increase in log calls.  Step 705 < 2219; dropping {'valid_loss': 0.09256449341773987, 'valid_acc': 0.96875}.
# valid Epoch 9 :  53%|█████▎    | 39/74 [00:03<00:02, 16.38batch/s, acc=0.00839, loss=0.056] wandb: WARNING Step must only increase in log calls.  Step 706 < 2219; dropping {'valid_loss': 0.1316145807504654, 'valid_acc': 0.96875}.
# valid Epoch 9 :  55%|█████▌    | 41/74 [00:03<00:02, 14.86batch/s, acc=0.00858, loss=0.058]wandb: WARNING Step must only increase in log calls.  Step 707 < 2219; dropping {'valid_loss': 0.14495359361171722, 'valid_acc': 0.9375}.
# valid Epoch 9 :  55%|█████▌    | 41/74 [00:03<00:02, 14.86batch/s, acc=0.0088, loss=0.0583]wandb: WARNING Step must only increase in log calls.  Step 708 < 2219; dropping {'valid_loss': 0.025284212082624435, 'valid_acc': 1.0}.
# valid Epoch 9 :  58%|█████▊    | 43/74 [00:03<00:01, 15.81batch/s, acc=0.009, loss=0.0596] wandb: WARNING Step must only increase in log calls.  Step 709 < 2219; dropping {'valid_loss': 0.09680674970149994, 'valid_acc': 0.953125}.
# valid Epoch 9 :  58%|█████▊    | 43/74 [00:03<00:01, 15.81batch/s, acc=0.0092, loss=0.0614]wandb: WARNING Step must only increase in log calls.  Step 710 < 2219; dropping {'valid_loss': 0.12724225223064423, 'valid_acc': 0.96875}.
# valid Epoch 9 :  61%|██████    | 45/74 [00:03<00:01, 15.76batch/s, acc=0.0094, loss=0.0626]wandb: WARNING Step must only increase in log calls.  Step 711 < 2219; dropping {'valid_loss': 0.08808934688568115, 'valid_acc': 0.953125}.
# valid Epoch 9 :  61%|██████    | 45/74 [00:03<00:01, 15.76batch/s, acc=0.00961, loss=0.064]wandb: WARNING Step must only increase in log calls.  Step 712 < 2219; dropping {'valid_loss': 0.10734011232852936, 'valid_acc': 0.96875}.
# valid Epoch 9 :  64%|██████▎   | 47/74 [00:03<00:01, 15.56batch/s, acc=0.00981, loss=0.0651]wandb: WARNING Step must only increase in log calls.  Step 713 < 2219; dropping {'valid_loss': 0.08054019510746002, 'valid_acc': 0.953125}.
# valid Epoch 9 :  64%|██████▎   | 47/74 [00:03<00:01, 15.56batch/s, acc=0.01, loss=0.0668]   wandb: WARNING Step must only increase in log calls.  Step 714 < 2219; dropping {'valid_loss': 0.12828606367111206, 'valid_acc': 0.96875}.
# valid Epoch 9 :  66%|██████▌   | 49/74 [00:03<00:01, 15.69batch/s, acc=0.0102, loss=0.0675]wandb: WARNING Step must only increase in log calls.  Step 715 < 2219; dropping {'valid_loss': 0.050559986382722855, 'valid_acc': 0.984375}.
# valid Epoch 9 :  66%|██████▌   | 49/74 [00:03<00:01, 15.69batch/s, acc=0.0104, loss=0.0691]wandb: WARNING Step must only increase in log calls.  Step 716 < 2219; dropping {'valid_loss': 0.11529307812452316, 'valid_acc': 0.96875}.
# valid Epoch 9 :  69%|██████▉   | 51/74 [00:04<00:01, 15.58batch/s, acc=0.0106, loss=0.07]  wandb: WARNING Step must only increase in log calls.  Step 717 < 2219; dropping {'valid_loss': 0.06822315603494644, 'valid_acc': 0.96875}.
# valid Epoch 9 :  69%|██████▉   | 51/74 [00:04<00:01, 15.58batch/s, acc=0.0108, loss=0.0715]wandb: WARNING Step must only increase in log calls.  Step 718 < 2219; dropping {'valid_loss': 0.10657961666584015, 'valid_acc': 0.984375}.
# valid Epoch 9 :  72%|███████▏  | 53/74 [00:04<00:01, 14.88batch/s, acc=0.0111, loss=0.072] wandb: WARNING Step must only increase in log calls.  Step 719 < 2219; dropping {'valid_loss': 0.038776081055402756, 'valid_acc': 1.0}.
# valid Epoch 9 :  72%|███████▏  | 53/74 [00:04<00:01, 14.88batch/s, acc=0.0113, loss=0.0751]wandb: WARNING Step must only increase in log calls.  Step 720 < 2219; dropping {'valid_loss': 0.2299519181251526, 'valid_acc': 0.953125}.
# valid Epoch 9 :  74%|███████▍  | 55/74 [00:04<00:01, 15.68batch/s, acc=0.0115, loss=0.0771]wandb: WARNING Step must only increase in log calls.  Step 721 < 2219; dropping {'valid_loss': 0.14920607209205627, 'valid_acc': 0.9375}.
# valid Epoch 9 :  74%|███████▍  | 55/74 [00:04<00:01, 15.68batch/s, acc=0.0117, loss=0.0788]wandb: WARNING Step must only increase in log calls.  Step 722 < 2219; dropping {'valid_loss': 0.1262863725423813, 'valid_acc': 0.96875}.
# valid Epoch 9 :  77%|███████▋  | 57/74 [00:04<00:01, 16.37batch/s, acc=0.0119, loss=0.0827]wandb: WARNING Step must only increase in log calls.  Step 723 < 2219; dropping {'valid_loss': 0.2852700352668762, 'valid_acc': 0.921875}.
# valid Epoch 9 :  77%|███████▋  | 57/74 [00:04<00:01, 16.37batch/s, acc=0.0121, loss=0.0838]wandb: WARNING Step must only increase in log calls.  Step 724 < 2219; dropping {'valid_loss': 0.07843025028705597, 'valid_acc': 0.96875}.
# valid Epoch 9 :  80%|███████▉  | 59/74 [00:04<00:00, 16.30batch/s, acc=0.0123, loss=0.0848]wandb: WARNING Step must only increase in log calls.  Step 725 < 2219; dropping {'valid_loss': 0.08032363653182983, 'valid_acc': 0.953125}.
# valid Epoch 9 :  80%|███████▉  | 59/74 [00:04<00:00, 16.30batch/s, acc=0.0125, loss=0.0859]wandb: WARNING Step must only increase in log calls.  Step 726 < 2219; dropping {'valid_loss': 0.07955696433782578, 'valid_acc': 0.953125}.
# valid Epoch 9 :  82%|████████▏ | 61/74 [00:04<00:00, 16.75batch/s, acc=0.0127, loss=0.0865]wandb: WARNING Step must only increase in log calls.  Step 727 < 2219; dropping {'valid_loss': 0.043774716556072235, 'valid_acc': 0.984375}.
# valid Epoch 9 :  82%|████████▏ | 61/74 [00:04<00:00, 16.75batch/s, acc=0.0129, loss=0.0882]wandb: WARNING Step must only increase in log calls.  Step 728 < 2219; dropping {'valid_loss': 0.12120440602302551, 'valid_acc': 0.96875}.
# valid Epoch 9 :  85%|████████▌ | 63/74 [00:04<00:00, 17.31batch/s, acc=0.0131, loss=0.0906]wandb: WARNING Step must only increase in log calls.  Step 729 < 2219; dropping {'valid_loss': 0.1831558644771576, 'valid_acc': 0.9375}.
# valid Epoch 9 :  85%|████████▌ | 63/74 [00:04<00:00, 17.31batch/s, acc=0.0133, loss=0.0916]wandb: WARNING Step must only increase in log calls.  Step 730 < 2219; dropping {'valid_loss': 0.06882557272911072, 'valid_acc': 0.953125}.
# valid Epoch 9 :  88%|████████▊ | 65/74 [00:04<00:00, 17.50batch/s, acc=0.0135, loss=0.0923]wandb: WARNING Step must only increase in log calls.  Step 731 < 2219; dropping {'valid_loss': 0.057770244777202606, 'valid_acc': 0.984375}.
# valid Epoch 9 :  88%|████████▊ | 65/74 [00:04<00:00, 17.50batch/s, acc=0.0137, loss=0.0939]wandb: WARNING Step must only increase in log calls.  Step 732 < 2219; dropping {'valid_loss': 0.11179543286561966, 'valid_acc': 0.9375}.
# valid Epoch 9 :  91%|█████████ | 67/74 [00:04<00:00, 17.67batch/s, acc=0.0139, loss=0.0944]wandb: WARNING Step must only increase in log calls.  Step 733 < 2219; dropping {'valid_loss': 0.03717436268925667, 'valid_acc': 1.0}.
# valid Epoch 9 :  91%|█████████ | 67/74 [00:05<00:00, 17.67batch/s, acc=0.0141, loss=0.0953]wandb: WARNING Step must only increase in log calls.  Step 734 < 2219; dropping {'valid_loss': 0.06981248408555984, 'valid_acc': 0.984375}.
# valid Epoch 9 :  93%|█████████▎| 69/74 [00:05<00:00, 17.74batch/s, acc=0.0143, loss=0.096] wandb: WARNING Step must only increase in log calls.  Step 735 < 2219; dropping {'valid_loss': 0.05112866684794426, 'valid_acc': 0.984375}.
# valid Epoch 9 :  93%|█████████▎| 69/74 [00:05<00:00, 17.74batch/s, acc=0.0145, loss=0.0972]wandb: WARNING Step must only increase in log calls.  Step 736 < 2219; dropping {'valid_loss': 0.08941785246133804, 'valid_acc': 0.96875}.
# valid Epoch 9 :  96%|█████████▌| 71/74 [00:05<00:00, 17.82batch/s, acc=0.0147, loss=0.0982]wandb: WARNING Step must only increase in log calls.  Step 737 < 2219; dropping {'valid_loss': 0.07274404168128967, 'valid_acc': 0.96875}.
# valid Epoch 9 :  96%|█████████▌| 71/74 [00:05<00:00, 17.82batch/s, acc=0.0149, loss=0.0992]wandb: WARNING Step must only increase in log calls.  Step 738 < 2219; dropping {'valid_loss': 0.07708149403333664, 'valid_acc': 0.984375}.
# valid Epoch 9 :  99%|█████████▊| 73/74 [00:05<00:00, 17.26batch/s, acc=0.0151, loss=0.1]   wandb: WARNING Step must only increase in log calls.  Step 739 < 2219; dropping {'valid_loss': 0.08217883855104446, 'valid_acc': 0.9811320754716981}.
# valid Epoch 9 : 100%|██████████| 74/74 [00:05<00:00, 13.74batch/s, acc=0.0151, loss=0.1]
# train Epoch 10 :  15%|█▍        | 33/222 [00:13<00:58,  3.23batch/s, acc=0.00231, loss=0.019]

# %% [markdown]
# # 4. 추론

# %%
class TestDataset(Dataset):
    def __init__(self, img_paths, transform):
        self.img_paths = img_paths
        self.transform = transform

    def __getitem__(self, index):
        image = PIL.Image.open(self.img_paths[index])
        image = np.array(image.convert("RGB"))
        if self.transform:
            image = self.transform(image=image)
            image = image['image']
        return image

    def __len__(self):
        return len(self.img_paths)

# %%
model.load_state_dict(torch.load('/opt/ml/image-classification-level1-04/saved/models/20210830_195228/baseline_vit_base_patch16_384_lr1e-05_stepLR5_batch16_epoch22_valid_loss_0.00184.pt'))

# %%
submission = pd.read_csv(os.path.join(test_dir, 'info.csv'))
image_dir = os.path.join(test_dir, 'new_images')

image_paths = [os.path.join(image_dir, img_id) for img_id in submission.ImageID]
dataset = TestDataset(image_paths, A_transform['test'])
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

torch.load

model.eval()
all_predictions = []
with tqdm(test_loader, total=test_loader.__len__(), unit="batch") as test_bar:
    for images in test_bar:
        with torch.no_grad():
            images = images.to(device)
            pred = model(images)
            pred = pred.argmax(dim=-1)
            all_predictions.extend(pred.cpu().numpy())
    
submission['ans'] = all_predictions
submission.to_csv(os.path.join(test_dir, 'submission.csv'), index=False)
print('test inference is done!')
# Out:
# 100%|██████████| 788/788 [03:25<00:00,  3.83batch/s]
# test inference is done!
